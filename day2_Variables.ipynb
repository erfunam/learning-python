# %%
a = 2
a = a + 2
print(a)
# Out:
# 4

# %%
b = 2
b += 2
print(b)
# Out:
# 4

# %%
c = 2
c -= 2
print(c)
# Out:
# 0

# %%
d = 3
d *= 2
print(d)
# Out:
# 6

# %%
e = 3
e **= 2
print(e)
# Out:
# 9

# %%
masahat = a * b 
print(masahat)
# Out:
# 16
