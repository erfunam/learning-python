# %%
#data type
#int = 1, 2, 3, 4 ...
#float = 1.5, 3.14
#string = "Hello, World!"
#list = ["sos", 5, 3.14, false] ... mutable
#dic = {"apple": 1500, "orange": 1200} 
#tuple = ("pizza", 5, 3.14, false) ... immutable
#set = ["pizza", 5, 3.14, false] ... irreplaceable
#bool = True, False

# %%
#Addition +
print(6 + 9)
# Out:
# 15

# %%
#Subtraction -
print(6 - 9)
# Out:
# 3

# %%
#Multiplication *
print(6 * 9)
# Out:
# 54

# %%
#Division /
print(6 / 3)
# Out:
# 2.0

# %%
#Floor Division //
print(6 // 3)
# Out:
# 2

# %%
#Modulus %
print(9 % 2)
# Out:
# 1

# %%
#Exponentiation **
print(6 ** 9)
# Out:
# 10077696
