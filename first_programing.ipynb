# %%
payam = "hello jafari"

# %%
print (payam)
# Out:
# hello jafari

# %%
print(payam[0])
# Out:
# h

# %%
print(payam[0:6])
# Out:
# hello

# %%
print(payam[-6:-1])
# Out:
# jafar

# %%
ns = "0123456789"

# %%
ns [4]
# Out:
# '4'

# %%
ns [-1]
# Out:
# '9'

# %%
ns[::-1]
# Out:
# '9876543210'

# %%
ns [::]
# Out:
# '0123456789'

# %%
type (ns)
# Out:
# str

# %%
type (payam)
# Out:
# str

# %%
adad = 55

# %%
type (adad)
# Out:
# int

# %%
length(ns)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 length(ns)
#
# NameError: name 'length' is not defined

# %%
count(ns)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 count(ns)
#
# NameError: name 'count' is not defined

# %%
len(ns)
# Out:
# 10

# %%
x = 'Hi this is a string'

# %%
x.lower()
# Out:
# 'hi this is a string'

# %%
x=x.lower()
x.split()
# Out:
# ['hi', 'this', 'is', 'a', 'string']

# %%
list[1,2,3,4]
# Out:
# list[1, 2, 3, 4]

# %%
list.__add__(4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 list.__add__(4)
#
# TypeError: descriptor '__add__' requires a 'list' object but received a 'int'

# %%
list.append(7)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 list.append(7)
#
# TypeError: descriptor 'append' for 'list' objects doesn't apply to a 'int' object

# %%
nomre ={"matin": {"maram":20,"kon":10},"parsa":{"maram":17,"maghz":23}}

# %%
nomre ["matin"]["maram"]
# Out:
# 20

# %%
print(nomre ["matin"]["kon"])
# Out:
# 10

# %%
nomre.values()
# Out:
# dict_values([{'maram': 20, 'kon': 10}, {'maram': 17, 'maghz': 23}])

# %%
nomre.keys()
# Out:
# dict_keys(['matin', 'parsa'])

# %%
nomre.items()
# Out:
# dict_items([('matin', {'maram': 20, 'kon': 10}), ('parsa', {'maram': 17, 'maghz': 23})])

# %%
nomre.append("city", "Tehran")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 nomre.append("city", "Tehran")
#
# AttributeError: 'dict' object has no attribute 'append'

# %%
nomre.add("city", "Tehran")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[65], line 1
# ----> 1 nomre.add("city", "Tehran")
#
# AttributeError: 'dict' object has no attribute 'add'

# %%
nomre.insert("city", "Tehran")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[66], line 1
# ----> 1 nomre.insert("city", "Tehran")
#
# AttributeError: 'dict' object has no attribute 'insert'

# %%
nomre["city"] = "Tehran":

# %%
nomre.values()
# Out:
# dict_values([{'maram': 20, 'kon': 10}, {'maram': 17, 'maghz': 23}, 'Tehran'])

# %%
nomre
# Out:
# {'matin': {'maram': 20, 'kon': 10},
#  'parsa': {'maram': 17, 'maghz': 23},
#  'city': 'Tehran'}

# %%
nomre["erfan"] = {"maram":100,"kon":1}

# %%
print(nomre)
# Out:
# {'matin': {'maram': 20, 'kon': 10}, 'parsa': {'maram': 17, 'maghz': 23}, 'city': 'Tehran', 'erfan': {'maram': 100, 'kon': 1}}

# %%
fruit_prices = {"apple":1500, "banana":1000, "orang":1200}

# %%
fruit_prices ["banana"] = 1100
del fruit_prices ["apple"]

# %%
print(fruit_prices)
# Out:
# {'banana': 1100, 'orang': 1200}

# %%
t1 = (1,2,3,4,5)

# %%
refigh = ("matin","abol")
ref1,ref2=refigh

# %%
ref1
# Out:
# 'matin'

# %%
coordinates = ()
distance = √((x₂ - x₁)² + (y₂ - y₁)²)
# Out:
#   Cell In[90], line 2
#     distance = √((x₂ - x₁)² + (y₂ - y₁)²)
#                ^
# SyntaxError: invalid character '√' (U+221A)
