# %%
#comma separated values

# %%
import csv

my_csv = open("day6_Csv.csv", encoding='utf-8')

csv_data = csv.reader(my_csv)

for line in csv_data :
    print(line)
# Out:
# ['Product Name', 'Price', 'Quantity']
# ['Apple', '1500', '5']
# ['Banana', '1000', '10']
# ['Orange', '1200', '3']
# ['Grapes', '2000', '2']

# %%
my_csv.close()

my_csv = open("day6_Csv.csv", encoding='utf-8')

csv_data = csv.reader(my_csv)

csv_list_lines = list(csv_data)

# %%
print(csv_list_lines)
# Out:
# [['Product Name', 'Price', 'Quantity'], ['Apple', '1500', '5'], ['Banana', '1000', '10'], ['Orange', '1200', '3'], ['Grapes', '2000', '2']]

# %%
for this_line in csv_list_lines:
    print(this_line[0])
# Out:
# Product Name
# Apple
# Banana
# Orange
# Grapes

# %%
my_csv.close()

my_csv = open("day6_Csv.csv", encoding='utf-8')

csv_data = csv.DictReader(my_csv)

csv_data

# %%
lines = list(csv_data)

# %%
lines
# Out:
# [{'Product Name': 'Apple', 'Price': '1500', 'Quantity': '5'},
#  {'Product Name': 'Banana', 'Price': '1000', 'Quantity': '10'},
#  {'Product Name': 'Orange', 'Price': '1200', 'Quantity': '3'},
#  {'Product Name': 'Grapes', 'Price': '2000', 'Quantity': '2'}]

# %%
my_csv.close()

outFile = open("day6_Csv.csv", mode= 'w', newline='')

csv_writer = csv.writer(outFile, delimiter=',')

csv_writer.writerow([1, 2, 3])

csv_writer.writerow(['avocado', 3000, 5])

outFile.close()
