# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
2 > 1
# Out:
# True

# %%
2 > 3
# Out:
# False

# %%
age = 20
age <= 25
# Out:
# True

# %%
age == 19
# Out:
# False

# %%
a = True
type(a)
# Out:
# bool

# %%
#None is no true and no false

# %%
type(None)
# Out:
# NoneType

# %%
strNum = "123"
strNum.isdigit()
# Out:
# True

# %%
myList = [1, 4, 3.14, "erfan"]
"erfan" in myList
# Out:
# True

# %%
3.14 in myList
# Out:
# True

# %%
heyvoonha = {"dog": 3,"cat": 5,"sheep": 0}
'cat' in heyvoonha
# Out:
# True

# %%
'cow' in heyvoonha
# Out:
# False
