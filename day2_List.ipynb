# %%
#List is ordered
mylist = [0, 5, 5, 6, 3.14, "Jafari", False]
print(mylist)
# Out:
# [0, 5, 5, 6, 3.14, 'Jafari', False]

# %%
type(mylist)
# Out:
# list

# %%
print(mylist[0:2])
# Out:
# [0, 5]

# %%
print(mylist[:-1])
# Out:
# [0, 5, 5, 6, 3.14, 'Jafari']

# %%
print(mylist[0:6:1])
# Out:
# [0, 5, 5, 6, 3.14, 'Jafari']

# %%
print(mylist[7:0:-1])
# Out:
# [False, 'Jafari', 3.14, 6, 5, 5]

# %%
print(mylist[::-1])
# Out:
# [False, 'Jafari', 3.14, 6, 5, 5, 0]

# %%
len("Jafari")
# Out:
# 6

# %%
len(mylist)
# Out:
# 7

# %%
mylist2 = [1, 2, 3, 4, True]

# %%
print(mylist + mylist2)
# Out:
# [0, 5, 5, 6, 3.14, 'Jafari', False, 1, 2, 3, 4, True]

# %%
mylist2.pop()
# Out:
# True

# %%
mylist2
# Out:
# [1, 2, 3, 4]

# %%
num = [3.14, 15, 1, 7, 99]
num.sort()
print(num)
# Out:
# [1, 3.14, 7, 15, 99]

# %%
num [1] = 3.1515
print(num)
# Out:
# [1, 3.1515, 7, 15, 99]

# %%
num.remove(99)
print(num)
# Out:
# [1, 3.1515, 7, 15]

# %%
num.append(85)
print(num)
# Out:
# [1, 3.1515, 7, 15, 85]

# %%
rev = [1, 2, 3, 4, 5]
rev.reverse()
print(rev)
# Out:
# [5, 4, 3, 2, 1]

# %%
l69 = [1, 2, 3, [1, 2, 3]]
print(l69 [3][1])
# Out:
# 2
