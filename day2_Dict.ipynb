# %%
nomre = {"Math": 18, "Physic": 17}
nomre ["Math"]
# Out:
# 18

# %%
celass = {"AbbasAli": {"Math": 15, "Physic": 16}, "Shantia": {"Math": 18, "Physic": 13}}

# %%
print(celass ["AbbasAli"])
# Out:
# {'Math': 15, 'Physic': 16}

# %%
print(celass ["Shantia"]["Math"])
# Out:
# 18

# %%
celass.values()
# Out:
# dict_values([{'Math': 15, 'Physic': 16}, {'Math': 18, 'Physic': 13}])

# %%
celass.keys()
# Out:
# dict_keys(['AbbasAli', 'Shantia'])

# %%
celass.get("AbbasAli")
# Out:
# {'Math': 15, 'Physic': 16}

# %%
celass.get("Amir", -1)
# Out:
# -1

# %%
celass.get("Shantia", -1)
# Out:
# {'Math': 18, 'Physic': 13}

# %%
celass.items()
# Out:
# dict_items([('AbbasAli', {'Math': 15, 'Physic': 16}), ('Shantia', {'Math': 18, 'Physic': 13})])

# %%
num = {"lst1": [1, 2, 3, 4], "lst2": [5, 6, 7 ,8]}
print(num["lst2"][2])
# Out:
# 7

# %%
kelasha = {1: ["jafari", "heydari", "gholami"], 2: ["eshghi", "ferdosi", "mazaheri"]}

# %%
kelasha [1]
# Out:
# ['jafari', 'heydari', 'gholami']

# %%
kelasha [2][2]
# Out:
# 'mazaheri'

# %%
fruit_price = {"apple": 150000, "banana": 200000, "orange": 120000}
fruit_price ["banana"] = 180000
fruit_price.pop("apple", None)
print(fruit_price)
# Out:
# {'banana': 180000, 'orange': 120000}

# %%
fruit_price = {"apple": 150000, "banana": 200000, "orange": 120000}
fruit_price ["banana"] = 180000
del fruit_price ["apple"]
print(fruit_price)
# Out:
# {'banana': 180000, 'orange': 120000}

# %%
fruit_price.clear()
print(fruit_price)
# Out:
# {}
