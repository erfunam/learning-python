# %%
pwd
# Out:
# 'c:\\Users\\erfan\\Desktop\\olamp\\python learn\\learning-python'

# %%
f = open("day3_FileIO_test.txt")

# %%
type(f)
# Out:
# _io.TextIOWrapper

# %%
f.read()
# Out:
# "Hello, I'm Erfan.\nI'm learning.\nI hope everyone makes progress."

# %%
f.read()
# Out:
# ''

# %%
f.seek(0)
# Out:
# 0

# %%
f.read()
# Out:
# "Hello, I'm Erfan.\nI'm learning.\nI hope everyone makes progress."

# %%
f.seek(0)
# Out:
# 0

# %%
print(f.readline())
# Out:
# Hello, I'm Erfan.

# %%
f.close()

# %%
output = open("day3_FileIO_test.txt", "a")
output.write("\nNew line is here!")
# Out:
# 18

# %%
output.close()
