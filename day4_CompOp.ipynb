# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
6 > 9
# Out:
# False

# %%
6 < 9
# Out:
# True

# %%
"Erfan" == "Erfan"
# Out:
# True

# %%
name = "Erfan"
name == "erfan"
# Out:
# False

# %%
6 != 9
# Out:
# True

# %%
6 != 6
# Out:
# False

# %%
'erfan' > 'mohiyodin'
# Out:
# False

# %%
2 == 2
# Out:
# True

# %%
2 == '2'
# Out:
# False

# %%
6 < 9 and 6 <= 6
# Out:
# True

# %%
6 < 9 and 6 >= 9
# Out:
# False

# %%
6 < 9 or 6 >= 9
# Out:
# True

# %%
(6 < 9 or 6 >= 9) and (6 < 9 and 6 <= 6)
# Out:
# True

# %%
not (6 < 9)
# Out:
# False

# %%
not (6 < 9) == (6 >= 9)
# Out:
# True

# %%
6 < 8 < 9
# Out:
# True

# %%
ghad = 180
(150 < ghad) and (ghad < 200)
# Out:
# True

# %%
150 < ghad < 200
# Out:
# True
