# %%
mive = set()
mive.add("apple")
mive.add("orange")
mive.add("khiar")
print(mive)
# Out:
# {'orange', 'apple'}

# %%
sabzijat = set()
sabzijat.add("havij")
sabzijat.add("khiar")
sabzijat.add("goje")
print(sabzijat)
# Out:
# {'havij', 'goje', 'khiar'}

# %%
mive.union(sabzijat)
# Out:
# {'apple', 'goje', 'havij', 'khiar', 'orange'}

# %%
mive.intersection(sabzijat)
# Out:
# set()

# %%
type(mive)
# Out:
# set

# %%
type(sabzijat)
# Out:
# set

# %%
heyvoon = set(["dog","cat","cow","sheep","dog","cat","cow"])
print(heyvoon)
# Out:
# {'cat', 'sheep', 'dog', 'cow'}

# %%
type(heyvoon)
# Out:
# set

# %%
lstHeyvoon = ["dog","cat","cow","sheep","dog","cat","cow"]
heyvoonimlist = set (lstHeyvoon)
print(heyvoon)
# Out:
# {'cat', 'sheep', 'dog', 'cow'}

# %%
my_set = {1, 2, 2, 3, 4, 4, 5}
print(my_set)
# Out:
# {1, 2, 3, 4, 5}

# %%
SetA = {1, 2, 3, 4}
SetB = {3, 4, 5, 6}

unionSet = SetA.union(SetB)
intersectionSet = SetA.intersection(SetB)

print(unionSet)
print(intersectionSet)
# Out:
# {1, 2, 3, 4, 5, 6}
# {3, 4}
